# %%
#import needed libraries
import numpy as np
import pandas as pd

# %%
#load the dataset
data=pd.read_csv(r"C:\Users\hp\Downloads\archive(1)\netflix_titles.csv")

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.size
# Out:
# 105684

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data.drop('show_id',inplace=True,axis=1)

# %%
data.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 757.0+ KB

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data[data['title'].isin(['House of Cards'])]
# Out:
#          type           title director  \
# 1059  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
data['title'].str.contains('House of Cards')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
data.dtypes
# Out:
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['release_year'].value_counts().head()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# Name: release_year, dtype: int64

# %%
data['release_year'].value_counts().head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.groupby('type').title.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: title, dtype: int64

# %%
sns.countplot(data['type'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
data[(data['type']=='Movie')&(data['release_year']==2021)]
# Out:
#        type                                              title  \
# 6     Movie                   My Little Pony: A New Generation
# 9     Movie                                       The Starling
# 12    Movie                                       Je Suis Karl
# 13    Movie                   Confessions of an Invisible Girl
# 18    Movie                                          Intrusion
# ...     ...                                                ...
# 1425  Movie                        Creating The Queen's Gambit
# 1431  Movie                                        Stuck Apart
# 1436  Movie  Ratones Paranoicos: The Band that Rocked Argen...
# 1466  Movie                       The Minimalists: Less Is Now
# 1468  Movie                          What Happened to Mr. Cha?
#
#                              director  \
# 6       Robert Cullen, José Luis Ucha
# 9                      Theodore Melfi
# 12                Christian Schwochow
# 13                      Bruno Garotti
# ...

# %%
data[(data['type']=='TV Show')&(data['country']=='India')]
# Out:
#          type                               title director  \
# 4     TV Show                        Kota Factory      NaN
# 39    TV Show                        Chhota Bheem      NaN
# 50    TV Show                       Dharmakshetra      NaN
# 66    TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69    TV Show      Stories by Rabindranath Tagore      NaN
# ...       ...                                 ...      ...
# 8173  TV Show                           Thackeray      NaN
# 8235  TV Show                         The Calling    Bumpy
# 8321  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349  TV Show              The House That Made Me      NaN
# 8775  TV Show                     Yeh Meri Family      NaN
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# ...

# %%
data[(data['type']=='TV Show')&(data['country']=='India')]['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Jay Chapman               12
# Martin Scorsese           12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
data['director'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data[(data['type']=='Movie')&(data['listed_in']=='Comedies')]
# Out:
#        type                                   title              director  \
# 27    Movie                               Grown Ups          Dennis Dugan
# 152   Movie           Janoskians: Untold and Untrue          Brett Weiner
# 182   Movie             Welcome Home Roscoe Jenkins        Malcolm D. Lee
# 342   Movie                             Major Payne           Nick Castle
# 348   Movie                                    Poms            Zara Hayes
# ...     ...                                     ...                   ...
# 8420  Movie              The Men Who Stare at Goats          Grant Heslov
# 8433  Movie  The Naked Gun 2 1/2: The Smell of Fear          David Zucker
# 8536  Movie                       The Trip to Spain  Michael Winterbottom
# 8608  Movie                        Total Frat Movie      Warren P. Sonoda
# 8730  Movie                       Where's the Money       Scott Zabielski
#
#                                                    cast  \
# ...

# %%
data[(data['type']=='Movie')&(data['listed_in']=='Comedies') | (data['country']=='United Kingdom')]
# Out:
#          type                                   title         director  \
# 8     TV Show           The Great British Baking Show  Andy Devonshire
# 27      Movie                               Grown Ups     Dennis Dugan
# 32    TV Show                           Sex Education              NaN
# 65    TV Show                            Numberblocks              NaN
# 72    TV Show  Jack Whitehall: Travels with My Father              NaN
# ...       ...                                     ...              ...
# 8740  TV Show                             Wild Alaska              NaN
# 8741  TV Show                             Wild Arabia              NaN
# 8744    Movie                                Williams  Morgan Matthews
# 8758  TV Show                  World's Busiest Cities              NaN
# 8786    Movie                            You Can Tutu      James Brown
#
#                                                    cast         country  \
# ...

# %%
data[(data['type']=='Movie')&(data['listed_in']=='Comedies') | (data['country']=='India')]
# Out:
#          type                title                 director  \
# 4     TV Show         Kota Factory                      NaN
# 24      Movie                Jeans               S. Shankar
# 27      Movie            Grown Ups             Dennis Dugan
# 39    TV Show         Chhota Bheem                      NaN
# 50    TV Show        Dharmakshetra                      NaN
# ...       ...                  ...                      ...
# 8773    Movie  Yanda Kartavya Aahe             Kedar Shinde
# 8775  TV Show      Yeh Meri Family                      NaN
# 8798    Movie             Zed Plus  Chandra Prakash Dwivedi
# 8799    Movie                Zenda           Avadhoot Gupte
# 8806    Movie               Zubaan              Mozez Singh
#
#                                                    cast        country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...          India
# ...
